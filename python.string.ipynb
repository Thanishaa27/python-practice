# %%
a="hello world"
print(a[:2])
# Out:
# he

# %%
a="hello world"
print(a[2:])
# Out:
# llo world

# %%
a="hello world"
print(a[:-2])
print(a[-2:])
print(a[1:-3])
# Out:
# hello wor
# ld
# ello wo

# %%
#rev a string(formatting string(with syntax),using conditional loop for)...imp
str="hello world"
print(str[::-1])
print(str[::-2])
print(str[::2])
print(str[2::])
print(str[-2::])
print(str[::-4])
print(str[0:11:2])
# Out:
# dlrow olleh
# drwolh
# hlowrd
# llo world
# ld
# dwl
# hlowrd

# %%
c="all is well"
print(c[::-1])
# Out:
# llew si lla

# %%
a=2*'chunnu'+'munnu'
print(a)
# Out:
# chunnuchunnumunnu

# %%
#take a user input as an integer.Use the nested if-else statement to determineand print whether the number is:positive and even,negative and odd,negative...imp,zero
a=int(input())
if a>0 and a%2==0:
    
 if a<0 and a%2!=0:
    print(a,"negative and odd")
else:
    print(a,"negative")
else:
    print(a,"zero")
# Out:
#   Cell In[39], line 6
#     else a<0:
#          ^
# SyntaxError: expected ':'

# %%
a=int(input())
if a>0:
    if a%2==0:
        print("Positive and even")
elif a<0 and a%2!=0:
    print("Negative and odd")
elif a<0:
    print("Negative")
else:
    print("zero")
# Out:
#  0
# zero
