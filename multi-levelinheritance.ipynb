# %%
#multi-level inheritance
#python program to calculate salary of the temporary staff using multilevel inheritance
class Person:
    def __init__(self,name):
        self.name=name
    def display(self):
        print("Name:",self.name)
class Staff(Person):
    def __init__(self):
        super().__init__()
        self.id=id
    def display(self):
        super().display()
        print("ID:",self.id)
class TemporaryStaff(Staff):
    def __init__(self,name,id,days,hoursworked):
        super().__init__()
        self.days=days
        self.hoursworked=hoursworked
    def Salary(self):
        salary=days*hoursworked*150
        return salary
    def display(self):
        super().display()
        print("No. of Days=",days)
        print("No. of hours worked=",hoursworked)
        print("Total Salary=",self.salary())
name=input()
Id=int(input())
days=int(input())
hoursworked=int(input())
ts=TemporaryStaff(name,id,days,hoursworked)
ts.display()
# Out:
#  tha
#  12
#  45
#  12
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 33
#      31 hoursworked=int(input())
#      32 ts=TemporaryStaff(name,id,days,hoursworked)
# ---> 33 ts.display()
#
# Cell In[7], line 24, in TemporaryStaff.display(self)
#      23 def display(self):
# ---> 24     super().display()
#      25     print("No. of Days=",days)
#      26     print("No. of hours worked=",hoursworked)
#
# AttributeError: 'super' object has no attribute 'display'
