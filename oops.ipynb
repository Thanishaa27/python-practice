# %%
class Python:
    def fun(self):
        print("welcome to opps concept")
pyt=Python()
pyt.fun()
# Out:
# welcome to opps concept

# %%
class Car:
    'Common_car'
    car=0
    def __init__(self,name,id):
        self.name=name
        self.id=id
        Car.car+=1
      
    def printCardata(self):
        print("Name:",self.name,"Id: ",self.id)
c=Car("AUDI",2000000)
c.printCardata()
# Out:
# Name: AUDI Id:  2000000

# %%
class Employee:
    def __init__(self,n,a,s):
          self.name=n
          self.age=a
          self.salary=s
    def display_data(self):
        print(self.name,self.age,self.salary)
e1=Employee("Thani",21,30000)
e1.display_data()
# Out:
# Thani 21 30000

# %%
class Birds:
    def __init__(self,n1,n2,n3):
          self.name=n1
          self.name1=n2
          self.name2=n3
    def display_data(self):
        print(self.name,self.name1,self.name2)
e1=Birds("Dove","Parrot","Peacock")
e1.display_data()
# Out:
# Dove Parrot Peacock

# %%
class Numbers:
    def __init__(self,num1):
          self.num1=num1
    def check_data(self):
        if self.num1>0:
            print("Positive")
        else:
            print("Negative")
n1=Numbers(26)
n1.check_data()
# Out:
# Positive

# %%
class Test:
    x=10
    def __init__(self):
        print("Hello")
t=Test()
print(Test.x)
# Out:
# Hello
# 10

# %%
class Car:
    'Common_car'
    car=0
    def __init__(self,name,id):
        self.name=name
        self.id=id
        Car.car+=1
      
    def printCardata(self):
        print("Name:",self.name,"Id: ",self.id)

c=Car("AUDI",2000000)
c1=Car("BENZ",3000000)
c2=Car("BENZ",10000000)
print("Total Cars:",Car.car)
c.printCardata()
c1.printCardata()
c2.printCardata()
# Out:
# Total Cars: 3
# Name: AUDI Id:  2000000
# Name: BENZ Id:  3000000
# Name: BENZ Id:  10000000

# %%
class test:
    def __init__(self):
        self.variable='Car'
        self.Change(self.variable)
    def Change(self,var):
        var='Bike'
obj=test()
print(obj.variable)
# Out:
# Car

# %%
class test:
    def __init__(self):
        self.variable='Car'
        self.Change(self.variable)
    def Change(self,var):
        
        self.var='Bike'
obj=test()
print(obj.variable)
print(obj.var);
# Out:
# Car
# Bike

# %%
class test:
    def __init__(self):
        self.variable='Car'
        self.Change(self.variable)
    def Change(self,var):
        
        var='Bike'
        print(var)
obj=test()
print(obj.variable)
# Out:
# Bike
# Car

# %%
class Demo:
    def __init__(self):
        pass
    def test(self):
        print(__name__)
obj=Demo()
obj.test()
# Out:
# __main__
