# %%
empty_tuple=()
print(empty_tuple)
# Out:
# ()

# %%
valuet=35,56,78
print(valuet)
# Out:
# (35, 56, 78)

# %%
v=(25,45,'hii',True)
v
# Out:
# (25, 45, 'hii', True)

# %%
Tuple=("hello")
print(Tuple,type(Tuple))
# Out:
# hello <class 'str'>

# %%
Tuple=("hello",)
print(Tuple,type(Tuple))
# Out:
# ('hello',) <class 'tuple'>

# %%
#immutable
b=(35,67,'helli')
b[1]=7
print(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 #immutable
#       2 b=(35,67,'helli')
# ----> 3 b[1]=7
#       4 print(b)
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1=(25,89,'hello')
t2=8,9.9,"python"
print(t1+t2)
# Out:
# (25, 89, 'hello', 8, 9.9, 'python')

# %%
#nesting of tuples
t1=(25,89,'hello')
t2=8,9.9,"python"
t3=t1,t2
t3
# Out:
# ((25, 89, 'hello'), (8, 9.9, 'python'))

# %%
#repetition in tuples
v_t=(25,56,'hello')*2
print(v_t)
# Out:
# (25, 56, 'hello', 25, 56, 'hello')

# %%
#accessing values in tuple
tuple=(26,45,'hello',7.5)
print(tuple[3])
# Out:
# 7.5

# %%
#slicing
tuple=(26,45,'hello',7.5)
print(tuple[0:])
print(tuple[2:])
print(tuple[:3])
print(tuple[:7])
print(tuple[2:])
print(tuple[:-4])
print(tuple[-4:])
print(tuple[::-1])
print(tuple[::-2])
print(tuple[-3::])
print(tuple[1::1])
print(tuple[-1::-2])
# Out:
# (26, 45, 'hello', 7.5)
# ('hello', 7.5)
# (26, 45, 'hello')
# (26, 45, 'hello', 7.5)
# ('hello', 7.5)
# ()
# (26, 45, 'hello', 7.5)
# (7.5, 'hello', 45, 26)
# (7.5, 45)
# (45, 'hello', 7.5)
# (45, 'hello', 7.5)
# (7.5, 45)

# %%
#looping
Tuple=('hello')
n=3
for i in range(int(n)):
    Tuple=(Tuple,)
    print(Tuple)
# Out:
# ('hello',)
# (('hello',),)
# ((('hello',),),)

# %%
#built in fun
t=(9,5,89,4,8)
print(max(t))
print(sum(t))
print(min(t))
print(sorted(t))
print(any(t))
# Out:
# 89
# 115
# 4
# [4, 5, 8, 9, 89]
# True

# %%
ex=()
print(ex)
# Out:
# ()

# %%
value_tuple=(26,45,'hello')
value_tuple
# Out:
# (26, 45, 'hello')

# %%
value=("a",)
type(value)
# Out:
# tuple

# %%
#insertion in tuple
t=(26,45,'helo',7.5)
t
# Out:
# (26, 45, 'helo', 7.5)

# %%
t[2]='python'
t
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 t[2]='python'
#       2 t
#
# TypeError: 'tuple' object does not support item assignment

# %%
value_1=(1,2,'hey')
value_2=(3,4,'hii')
value_3=value_1+value_2
print(value_3)
# Out:
# (1, 2, 'hey', 3, 4, 'hii')

# %%
#adding elements into the tuple
value_1=value_1+(7,)
value_1
# Out:
# (1, 2, 'hey', 7)

# %%
#another method type convsersion
value_1=(1,2,'hey')
converted_list=list(value_1)
converted_list
# Out:
# [1, 2, 'hey']

# %%
converted_list.append(7)
converted_list
# Out:
# [1, 2, 'hey', 7]

# %%
value_1=tuple(converted_list)
value_1
# Out:
# (1, 2, 'hey', 7)

# %%
#repetition
value_t=(26,45,'hello',)*2
print(value_t)
# Out:
# (26, 45, 'hello', 26, 45, 'hello')

# %%
#practice q:prgrm to get the tuple values from the user and print it
value=()
a=int(input())
list_1=[]
for i in range(a):
    list_1.append(int(input()))
value=tuple(list_1)
value
# Out:
#  3
#  23
#  45
#  56
# (23, 45, 56)
